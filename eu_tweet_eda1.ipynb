# %%
# %reset -fs

# %%
import pandas as pd
import numpy as np

# %%
df_en = pd.read_csv('eu_tweets_english.csv')
# Out:
# /var/folders/gc/kgfpjt4x1d5c1thdk2sl_2hr0000gn/T/ipykernel_15836/1700156901.py:1: DtypeWarning: Columns (0,1,2,3,4,7,9,10,11,13,15,16,17,18,19,21,26,27,28,30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_en = pd.read_csv('eu_tweets_english.csv')

# %%
df_en.shape
# Out:
# (4009626, 31)

# %%
df_en.columns
# Out:
# Index(['Unnamed: 0', 'created_at', 'hashtags', 'media', 'urls',
#        'favorite_count', 'id', 'in_reply_to_screen_name',
#        'in_reply_to_status_id', 'in_reply_to_user_id', 'lang', 'place',
#        'quote_id', 'retweet_count', 'retweet_id', 'retweet_screen_name',
#        'source', 'text', 'tweet_url', 'user_created_at', 'user_id',
#        'user_description', 'user_favourites_count', 'user_followers_count',
#        'user_friends_count', 'user_listed_count', 'user_location', 'user_name',
#        'user_screen_name', 'user_statuses_count', 'user_verified'],
#       dtype='object')

# %%
df_en.drop(['Unnamed: 0','media', 'urls','quote_id',
            'source', 'tweet_url'], axis=1, inplace=True)

# %%
df_en['id'].head()
# Out:
# 0    8.662391e+17
# 1    8.662327e+17
# 2    8.662368e+17
# 3    8.662369e+17
# 4    8.662337e+17
# Name: id, dtype: float64

# %%
df_en['id'].isnull().sum()
# Out:
# 56209

# %%
df_en[df_en['text'].isnull()]['id']
# Out:
# 3329        19411.0
# 6211            NaN
# 6212         1623.0
# 8413            NaN
# 8414        21157.0
#              ...
# 3164434      6400.0
# 3178106    149386.0
# 3196901     71439.0
# 3563772     42838.0
# 3833856     76541.0
# Name: id, Length: 56326, dtype: float64

# %%
rows_to_drop_index = df_en[df_en['text'].isnull()].index

# %%
df_en.drop(rows_to_drop_index, inplace=True)

# %%
print(df_en['id'].isnull().sum())
print(df_en['text'].isnull().sum())
# Out:
# 0
# 0

# %%
df_en.shape
# Out:
# (3953300, 25)

# %%
# df_en.reset_index(drop=True, inplace=True)

# %%
df_en.duplicated().sum()
# Out:
# 117536

# %%
df_dups_id = df_en[df_en.duplicated(subset='id')]
df_dups_id
# Out:
#                              created_at                      hashtags  \
# 5078     Sat May 27 07:10:49 +0000 2017              Harborough Oadby
# 75439    Sun Jul 16 08:42:28 +0000 2017                           NaN
# 264667   Tue Oct 10 09:10:30 +0000 2017  KirstyMaxwell Benidorm Spain
# 264668   Tue Oct 10 09:10:30 +0000 2017  KirstyMaxwell Benidorm Spain
# 264669   Tue Oct 10 09:10:30 +0000 2017  KirstyMaxwell Benidorm Spain
# ...                                 ...                           ...
# 3906518  Fri Mar 15 15:29:55 +0000 2019                           NaN
# 3916248  Wed Mar 20 15:05:49 +0000 2019                           NaN
# 3973169  Thu Apr 18 20:48:05 +0000 2019                         Malta
# 3992893  Tue Apr 30 09:39:50 +0000 2019                           NaN
# 3993914  Tue Apr 30 17:23:14 +0000 2019                           NaN
#
#          favorite_count            id in_reply_to_screen_name  \
# 5078                0.0  8.683638e+17                     NaN
# ...

# %%
df_en.drop_duplicates(subset='id', inplace=True, ignore_index=True)

# %%
df_en.duplicated(subset='id').sum()
# Out:
# 0

# %%
df_en.shape
# Out:
# (3835711, 25)

# %%
df_en.duplicated(subset=['text']).sum()
# Out:
# 646207

# %%
df_dups_text = df_en[df_en.duplicated(subset='text')]

# %%
df_dups_text.sort_values(by=['text']).text
# Out:
# 2370748    !  Macron ends his speech in English: “Make ou...
# 2370993    !  Macron ends his speech in English: “Make ou...
# 20895      ! @senatorwicker &amp; @sengillibrand introduc...
# 1611001    !! #5G networks and extends consumer protectio...
# 3523679    !! Yet again Health Secretary’s rhetoric on pr...
#                                  ...
# 2078227    🧵THREAD 👇\n\nThere’s a secret horror lurking i...
# 2078445    🧵THREAD 👇\n\nThere’s a secret horror lurking i...
# 2085255    🧵THREAD 👇\n\nThere’s a secret horror lurking i...
# 2085169    🧵THREAD 👇\n\nThere’s a secret horror lurking i...
# 2078255    🧵THREAD 👇\n\nThere’s a secret horror lurking i...
# Name: text, Length: 646207, dtype: object

# %%
df_en.drop_duplicates(subset='text', inplace=True, ignore_index=True)

# %%
df_en.shape
# Out:
# (3189504, 25)

# %%
df_en['id'] = df_en['id'].astype('int')

# %%
df_en['id']
# Out:
# 0           866239077045207040
# 1           866232717196840960
# 2           866236815463862272
# 3           866236868404314112
# 4           866233710714257408
#                   ...
# 3189499    1125114865423613952
# 3189500    1124728667555467264
# 3189501    1124391243885289472
# 3189502    1124682517389426688
# 3189503    1124668256990707712
# Name: id, Length: 3189504, dtype: int64

# %%
df_en.columns
# Out:
# Index(['created_at', 'hashtags', 'favorite_count', 'id',
#        'in_reply_to_screen_name', 'in_reply_to_status_id',
#        'in_reply_to_user_id', 'lang', 'place', 'retweet_count', 'retweet_id',
#        'retweet_screen_name', 'text', 'user_created_at', 'user_id',
#        'user_description', 'user_favourites_count', 'user_followers_count',
#        'user_friends_count', 'user_listed_count', 'user_location', 'user_name',
#        'user_screen_name', 'user_statuses_count', 'user_verified'],
#       dtype='object')

# %%
df_en.head()
# Out:
#                        created_at                   hashtags  favorite_count  \
# 0  Sun May 21 10:27:44 +0000 2017                        NaN             0.0
# 1  Sun May 21 10:02:28 +0000 2017                    Wigston             0.0
# 2  Sun May 21 10:18:45 +0000 2017  Natura2000Day blueeconomy             0.0
# 3  Sun May 21 10:18:57 +0000 2017                        NaN             0.0
# 4  Sun May 21 10:06:25 +0000 2017                        NaN             1.0
#
#                    id in_reply_to_screen_name  in_reply_to_status_id  \
# 0  866239077045207040                     NaN                    NaN
# 1  866232717196840960                     NaN                    NaN
# 2  866236815463862272                     NaN                    NaN
# 3  866236868404314112                     NaN                    NaN
# 4  866233710714257408              Cacophonic           8.662318e+17
#
#   in_reply_to_user_id lang            place retweet_count  ...  \
# ...

# %%
df_en.columns
# Out:
# Index(['created_at', 'hashtags', 'favorite_count', 'id',
#        'in_reply_to_screen_name', 'in_reply_to_status_id',
#        'in_reply_to_user_id', 'lang', 'place', 'retweet_count', 'retweet_id',
#        'retweet_screen_name', 'text', 'user_created_at', 'user_id',
#        'user_description', 'user_favourites_count', 'user_followers_count',
#        'user_friends_count', 'user_listed_count', 'user_location', 'user_name',
#        'user_screen_name', 'user_statuses_count', 'user_verified'],
#       dtype='object')

# %%
df_en = df_en[[ 'id','created_at', 'text', 'user_name','user_screen_name', 'user_id', 
            'user_description','user_location','user_verified','lang', 'place',
            'hashtags',
            'favorite_count', 
            'in_reply_to_screen_name', 'in_reply_to_status_id',
            'in_reply_to_user_id', 
            'retweet_count', 'retweet_id','retweet_screen_name', 'user_created_at',
            'user_favourites_count', 'user_followers_count', 
            'user_friends_count', 'user_listed_count', 
             'user_statuses_count' ]]

# %%
df_en.head()
# Out:
#                    id                      created_at  \
# 0  866239077045207040  Sun May 21 10:27:44 +0000 2017
# 1  866232717196840960  Sun May 21 10:02:28 +0000 2017
# 2  866236815463862272  Sun May 21 10:18:45 +0000 2017
# 3  866236868404314112  Sun May 21 10:18:57 +0000 2017
# 4  866233710714257408  Sun May 21 10:06:25 +0000 2017
#
#                                                 text  \
# 0  Pounding the streets of Redland this morning w...
# 1  The UKIP BATTLE BUS is coming; please support ...
# 2  Yesterday was 10th European Maritime Day, toda...
# 3  .@theSNP Depute Leader and candidate for Moray...
# 4  @Cacophonic That, and fox hunting and dementia...
#
#                      user_name user_screen_name      user_id  \
# 0                 Green💚🌻Molly  GreenPartyMolly  726372601.0
# 1            Dr Julia Reid PhD       julia_reid   43554444.0
# 2  Catherine Bearder🇪🇺 🇺🇦🇺🇦🇪🇺🔶     catherinemep  454779231.0
# 3                 Ian Hudghton      HudghtonSNP  308677137.0
# ...

# %%
df_en['user_id'] = df_en['user_id'].fillna(0).astype(int)

# %%
df_en['user_id'] = df_en['user_id'].astype('int')

# %%
df_en.head()
# Out:
#                    id                      created_at  \
# 0  866239077045207040  Sun May 21 10:27:44 +0000 2017
# 1  866232717196840960  Sun May 21 10:02:28 +0000 2017
# 2  866236815463862272  Sun May 21 10:18:45 +0000 2017
# 3  866236868404314112  Sun May 21 10:18:57 +0000 2017
# 4  866233710714257408  Sun May 21 10:06:25 +0000 2017
#
#                                                 text  \
# 0  Pounding the streets of Redland this morning w...
# 1  The UKIP BATTLE BUS is coming; please support ...
# 2  Yesterday was 10th European Maritime Day, toda...
# 3  .@theSNP Depute Leader and candidate for Moray...
# 4  @Cacophonic That, and fox hunting and dementia...
#
#                      user_name user_screen_name    user_id  \
# 0                 Green💚🌻Molly  GreenPartyMolly  726372601
# 1            Dr Julia Reid PhD       julia_reid   43554444
# 2  Catherine Bearder🇪🇺 🇺🇦🇺🇦🇪🇺🔶     catherinemep  454779231
# 3                 Ian Hudghton      HudghtonSNP  308677137
# ...

# %%
df_en.columns
# Out:
# Index(['id', 'created_at', 'text', 'user_name', 'user_screen_name', 'user_id',
#        'user_description', 'user_location', 'user_verified', 'lang', 'place',
#        'hashtags', 'favorite_count', 'in_reply_to_screen_name',
#        'in_reply_to_status_id', 'in_reply_to_user_id', 'retweet_count',
#        'retweet_id', 'retweet_screen_name', 'user_created_at',
#        'user_favourites_count', 'user_followers_count', 'user_friends_count',
#        'user_listed_count', 'user_statuses_count'],
#       dtype='object')

# %%
df_en.shape
# Out:
# (3189504, 25)

# %%
df_en.to_csv('eu_tweet_df_eda1.csv', index=False)

# %%
df_en.to_csv('eu_tweet_df_eda1_zip.csv.gz', index=False, compression='gzip')
